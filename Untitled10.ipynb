# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithkt/LSTM_stock/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
data = yf.download("RELIANCE.NS",period="5y",interval="1d")

print(data.head(5000))
print("Shape:",data.shape)
# Out:
# /tmp/ipykernel_5864/731537248.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("RELIANCE.NS",period="5y",interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2021-04-05   903.507080   918.198233   889.677428   918.175565    14875099
# 2021-04-06   899.743652   909.107004   892.806128   908.676254    14009194
# 2021-04-07   908.154846   928.128528   903.824613   906.862594    24266353
# 2021-04-08   909.288391   916.838010   903.688514   911.850286    15369188
# 2021-04-09   898.723450   909.741800   897.793885   906.159729    14037885
# ...                 ...          ...          ...          ...         ...
# 2026-03-25  1413.099976  1430.500000  1408.400024  1420.000000    19041331
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(data['Close'], label='Close Price')
plt.title("Reliance Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# Select only Close price
close_prices = data['Close'].values

# Convert to 2D
close_prices = close_prices.reshape(-1,1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(close_prices)

# %%
def create_sequences(data, window_size=45):
    X, y = [], []

    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])

    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, 45)

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (1191, 45, 1)
# y shape: (1191, 1)

# %%
train_size = int(len(X) * 0.8)

X_train = X[:train_size]
X_test = X[train_size:]

y_train = y[:train_size]
y_test = y[train_size:]

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import LSTM,Dense,Dropout

# %%
model = Sequential()

model.add(LSTM(units=500, return_sequences=True, input_shape=(500,1)))
model.add(Dropout(0.1))

model.add(LSTM(units=250, return_sequences=True))
model.add(Dropout(0.1))

model.add(LSTM(units=125, return_sequences=True))

model.add(LSTM(units=100, return_sequences=True))

model.add(LSTM(units=50, return_sequences=True))


model.add(Dense(units=25))
model.add(Dropout(0.1))

model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0724 - val_loss: 0.0901
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0261 - val_loss: 0.0457
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0195 - val_loss: 0.0359
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0169 - val_loss: 0.0318
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0156 - val_loss: 0.0298
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0153 - val_loss: 0.0351
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0145 - val_loss: 0.0237
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0145 - val_loss: 0.0241
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0134 - val_loss: 0.0245
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0134 - val_loss: 0.0265
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0130 - val_loss: 0.0212
# Epoch 12/50
# ...

# %%
predictions = model.predict(X_test)

# The model's last LSTM layer has return_sequences=True,
# which makes predictions a 3D array (num_samples, timesteps, features).
# However, for inverse transformation, a 2D array is expected.
# We'll take the last timestep's prediction for each sample,
# as y_test is also a 2D array (num_samples, 1), implying a many-to-one prediction.
predictions_reshaped = predictions[:, -1, :]

# Convert back to original scale
predictions = scaler.inverse_transform(predictions_reshaped)
y_test_actual = scaler.inverse_transform(y_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step

# %%
plt.figure(figsize=(10,5))

plt.plot(y_test_actual, label="Actual Price")
plt.plot(predictions, label="Predicted Price")

plt.title("Stock Price Prediction using LSTM")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# Get latest actual and predicted price
current_price = y_test_actual[-1][0]
predicted_price = predictions[-1][0]

# Calculate percentage change
change_percent = ((predicted_price - current_price) / current_price) * 100

print(f"Current Price: ₹{current_price:.2f}")
print(f"Predicted Price: ₹{predicted_price:.2f}")
print(f"Predicted Change: {change_percent:.2f}%")
# Out:
# Current Price: ₹1350.50
# Predicted Price: ₹1354.80
# Predicted Change: 0.32%

# %%
threshold = 2  # 2%

if change_percent > threshold:
    decision = "BUY"
elif change_percent < -threshold:
    decision = "SELL"
else:
    decision = "HOLD"

print(f"Recommendation: {decision}")
# Out:
# Recommendation: HOLD

# %%
confidence = abs(change_percent)

if confidence > 5:
    confidence_level = "High"
elif confidence > 2:
    confidence_level = "Medium"
else:
    confidence_level = "Low"

print(f"Confidence: {confidence_level}")
# Out:
# Confidence: Low
